# %%
import tensorflow as tf
from elections.Ballot import Ballot
from elections.DefaultConfigOptions import *
from elections.ElectionConstructor import ElectionConstructor, construct_irv, construct_h2h
from elections.NDPopulation import NDPopulation
from network.Tensor import Tensor
from network.ElectionModel import ElectionModel, ElectionModelTrainer
import pickle
import matplotlib.pyplot as plt

# %%
n_bins = 21
max_ideology = 1.5
min_ideology = -1.5
ideology_range = max_ideology - min_ideology
ideology_dim = 1
n_voters = 100

# %%
def create_model_and_population(ideology_bins: int, ideology_dim: int) -> (ElectionModel, NDPopulation):
    ideology_dim = 1
    ideology_bins = 32
    hidden_ratio = 4

    model = ElectionModel(n_bins, 256, 4)

    population_means = np.zeros(shape=(ideology_dim,))
    population_stddev = np.ones(shape=(ideology_dim,))
    pop = NDPopulation(population_means, population_stddev)
    return model, pop

# %%
def gen_random_candidates(population: NDPopulation, n: int)-> List[Candidate]:
    candidates = []
    while len(candidates) < n:
        ivec = population.unit_sample_voter().ideology.vec * .5
        if min_ideology < ivec[0] < max_ideology:
            candidates.append(Candidate(f"c-{len(candidates)}", Independents, Ideology(ivec), 0))

    return candidates

def run_sample_election(process: ElectionConstructor, population: NDPopulation, n_voters: int):
    candidates = gen_random_candidates(population, 5)
    voters = population.generate_unit_voters(n_voters)
    ballots = [Ballot(v, candidates, unit_election_config) for v in voters]
    result = process.run(ballots, set(candidates))
    winner = result.winner()
    return candidates, winner

def convert_ideology_to_bin(ideology: float) -> int:
    ideology = max(min_ideology, min(ideology, max_ideology))
    pct = (ideology - min_ideology) / ideology_range
    return int(pct * n_bins)

# note that the return value is the index of the winning candidate and NOT the
# bin of the winning candidate.
def create_training_sample(candidates: List[Candidate], winner: Candidate) -> (int, list[int]):
    w = candidates.index(winner)
    cc = [convert_ideology_to_bin(c.ideology.vec[0]) for c in candidates]
    return cc, w

# %%
import tensorflow as tf
import numpy as np

class ElectionMemory:
    def __init__(self, max_size: int, n_bins: int):
        self.max_size = max_size
        self.count = 0
        self.x: np.array = np.zeros(shape=(max_size, n_bins), dtype=np.single)
        self.mask: np.array = np.zeros(shape=(max_size, n_bins), dtype=np.single)
        self.y: np.array = np.zeros(shape=(max_size, n_bins), dtype=np.single)
        self.n_bins = n_bins


    # have to deal with the possibility that there will be two candidates
    # with same 'bin' and that one of them will have won.  Thus, we only
    # set the y to 1 for the candidate that won, a nearly identical example
    # will be created for the other candidate where y is 0.
    def add_sample(self, candidates: List[int], winner_index: int):
        for i in range(len(candidates)):
            x = np.zeros(shape=(1,self.n_bins), dtype=np.single)
            y = np.zeros(shape=(1, self.n_bins), dtype=np.single)
            mask = np.zeros(shape=(1,self.n_bins), dtype=np.single)
            for j in range(len(candidates)):
                if i != j:
                    x[0, candidates[j]] = 1

            if i == winner_index:
                y[0, candidates[winner_index]] = 1
            mask[0, candidates[i]] = 1

            self.add_sample_np(x, mask, y)

    def add_sample_np(self, x: np.ndarray, mask: np.ndarray, y: np.ndarray):
        sr = self.count % self.max_size
        self.count += x.shape[0]

        er = sr + x.shape[0]
        self.x[sr:er] = x
        self.mask[sr:er] = mask
        self.y[sr:er] = y


    def get_batch(self, batch_size) -> (np.ndarray, np.ndarray, np.ndarray):
        indices = np.random.randint(0, min(self.max_size, self.count), batch_size)
        return tf.gather(self.x, indices), tf.gather(self.mask, indices), tf.gather(self.y, indices)

# %%
def populate_dummy_memory() -> ElectionMemory:
    m = ElectionMemory(100000, n_bins)
    n_candidates = 5
    for i in range(100000):
        cc = [random.randrange(0, n_bins) for _ in range(n_candidates)]
        w = random.randrange(0, 5)
        m.add_sample(cc, w)

    return m

def test_election_memory():
    m = populate_dummy_memory()
    x, a, y = m.get_batch(4)
    print("x = ", x)
    print("a = ", a)
    print("y = ", y)

    print("done")
# test_election_memory()

# %%
class LossTracker():
    def __init__(self, count):
        self.count = count
        self.losses = np.zeros(shape=(count))
        self.idx = 0
        self.sum = 0

    def add_loss(self, l) -> float:
        idx = self.idx % self.count
        if self.idx >= self.count:
            self.sum -= self.losses[idx]
        self.sum += l
        self.losses[idx] = l
        self.idx += 1
        return self.sum / min(self.count, self.idx)

# %%
def populate_memory(count: int) -> ElectionMemory:
    m = ElectionMemory(count * 5, n_bins)
    population_means = np.zeros(shape=(ideology_dim,))
    population_stddev = np.ones(shape=(ideology_dim,))
    population = NDPopulation(population_means, population_stddev)
    process = ElectionConstructor(construct_irv, "IRV")
    print(f"populating training memory with {count * 5} samples")
    for i in range(count):
        c, w = run_sample_election(process, population, n_voters)
        ci, wi = create_training_sample(c, w)
        m.add_sample(ci, wi)
        if i % 100 == 0:
            print(".", end='')
    print(f"\nm.count {m.count}")
    return m

# %%
def train_network(net: ElectionModel,  memory: ElectionMemory, n_batches: int, batch_size: int):
    print(f"training network for {n_batches} epochs")
    tracker = LossTracker(1000)
    trainer = ElectionModelTrainer(net)
    current_path = ""
    average_loss = 0

    for i in range(n_batches):
        x, a, y = memory.get_batch(batch_size)
        loss = trainer.update(x, a, y)
        if np.isnan(loss):
            print(f"loss is nan, reverting to {current_path}")
            net = tf.keras.models.load_model(current_path)
            trainer = ElectionModelTrainer(net)
        else:
            average_loss = tracker.add_loss(loss)
            if i % 1000 == 0:
                print(f"epoch {i:5d} loss = {average_loss:.6}")
                current_path = f"mdl.sav.{i}"
                net.save(current_path, overwrite=True)

    return net, average_loss

# %%
def save_model_test():
    election_memory = populate_memory(1000)
    network = ElectionModel(n_bins, 256, 4)
    model_trainer = ElectionModelTrainer(network)
    train_network(network, election_memory, 100, 32)

    print("saving network")
    network.save("cm.sav", overwrite=True)
    print("loading n1")
    n1: ElectionModel = tf.keras.models.load_model("cm.sav")
    print("saving n1")
    n1.save("cm1.sav", overwrite=True)

    x, mask, y = election_memory.get_batch(1)

    print("network(x)")
    print(network(x))
    print("n1(x)")
    print(n1(x))
    print("bins: ", n1.n_bins)

save_model_test()
# Out:
# populating training memory with 5000 samples
# ..........
# m.count 5000
# training network for 100 epochs
# epoch     0 loss = 0.0424696
# saving network
# loading n1
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# saving n1
# network(x)
# tf.Tensor(
# [[0.00063517 0.00029125 0.00029273 0.0003061  0.00221351 0.01348361
#   0.02518798 0.02806755 0.21195006 0.10257724 0.19252694 0.11366741
#   0.14490388 0.08602922 0.05455501 0.01734561 0.00214756 0.0026406
#   0.00029359 0.00038627 0.00049872]], shape=(1, 21), dtype=float32)
# n1(x)
# tf.Tensor(
# [[0.00063517 0.00029125 0.00029273 0.0003061  0.00221351 0.01348361
#   0.02518798 0.02806755 0.21195006 0.10257724 0.19252694 0.11366741
#   0.14490388 0.08602922 0.05455501 0.01734561 0.00214756 0.0026406
#   0.00029359 0.00038627 0.00049872]], shape=(1, 21), dtype=float32)
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_6_layer_call_fn, dropout_6_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_6_layer_call_fn while saving (showing 5 of 35). These functions will not be directly callable after loading.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/bk/gdh16lyd147dmnfx84pr5n8c0000gn/T/ipykernel_38103/665254450.py in <module>
#      20     print("bins: ", n1.n_bins)
#      21
# ---> 22 save_model_test()
#      23
#
# /var/folders/bk/gdh16lyd147dmnfx84pr5n8c0000gn/T/ipykernel_38103/665254450.py in save_model_test()
#      18     print("n1(x)")
#      19     print(n1(x))
# ---> 20     print("bins: ", n1.n_bins)
#      21
#      22 save_model_test()
#
# AttributeError: 'ElectionModel' object has no attribute 'n_bins'

# %%
election_memory = populate_memory(50000)
# Out:
# populating training memory with 250000 samples
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# m.count 250000

# %%
def grid_search():
    tf.get_logger().setLevel('WARN')
    for batch_size in [2048]:
        for width in [256, 512]:
            for layers in [3, 4, 5]:
                network = ElectionModel(n_bins, width, layers)
                network, loss = train_network(network, election_memory, 10000, batch_size)
                print(f"batch_size {batch_size:4d} width {width:4d} layers {layers} loss {loss:.6}")
                network.save(f"networks/net.{batch_size}.{width}.{layers}.mdl")

grid_search()
# Out:
# training network for 10000 epochs
# epoch     0 loss = 0.0288365
# epoch   100 loss = 0.0243461
# epoch   200 loss = 0.0234561
# epoch   300 loss = 0.0231654
# epoch   400 loss = 0.0229549
# epoch   500 loss = 0.0228417
# epoch   600 loss = 0.0227424
# epoch   700 loss = 0.0226855
# epoch   800 loss = 0.0226378
# epoch   900 loss = 0.0225883
# epoch  1000 loss = 0.0225478
# epoch  1100 loss = 0.0222942
# epoch  1200 loss = 0.0222325
# epoch  1300 loss = 0.0221918
# epoch  1400 loss = 0.0221724
# epoch  1500 loss = 0.0221245
# epoch  1600 loss = 0.0220972
# epoch  1700 loss = 0.0220511
# epoch  1800 loss = 0.0220135
# epoch  1900 loss = 0.0219908
# epoch  2000 loss = 0.0219593
# epoch  2100 loss = 0.021977
# epoch  2200 loss = 0.0219647
# epoch  2300 loss = 0.0219248
# epoch  2400 loss = 0.0218868
# epoch  2500 loss = 0.0218579
# epoch  2600 loss = 0.0218372
# epoch  2700 loss = 0.0218024
# epoch  2800 loss = 0.0217642
# epoch  2900 loss = 0.0217346
# epoch  3000 loss = 0.0216962
# epoch  3100 loss = 0.0216548
# epoch  3200 loss = 0.0216275
# epoch  3300 loss = 0.0216077
# epoch  3400 loss = 0.0215891
# epoch  3500 loss = 0.0215602
# epoch  3600 loss = 0.0215165
# epoch  3700 loss = 0.0214838
# epoch  3800 loss = 0.0214498
# epoch  3900 loss = 0.0213934
# epoch  4000 loss = 0.0213594
# epoch  4100 loss = 0.0213378
# epoch  4200 loss = 0.0212925
# epoch  4300 loss = 0.021239
# epoch  4400 loss = 0.0211803
# epoch  4500 loss = 0.0211521
# epoch  4600 loss = 0.0211215
# epoch  4700 loss = 0.0210942
# epoch  4800 loss = 0.0210716
# epoch  4900 loss = 0.0210549
# epoch  5000 loss = 0.0210214
# epoch  5100 loss = 0.0209613
# epoch  5200 loss = 0.0209345
# epoch  5300 loss = 0.0209047
# epoch  5400 loss = 0.0208837
# epoch  5500 loss = 0.0208355
# epoch  5600 loss = 0.0208106
# epoch  5700 loss = 0.0207846
# epoch  5800 loss = 0.0207582
# epoch  5900 loss = 0.0207249
# epoch  6000 loss = 0.0206966
# epoch  6100 loss = 0.0206859
# epoch  6200 loss = 0.0206757
# epoch  6300 loss = 0.0206518
# epoch  6400 loss = 0.0206068
# epoch  6500 loss = 0.0205944
# epoch  6600 loss = 0.0205641
# epoch  6700 loss = 0.0205458
# epoch  6800 loss = 0.0205285
# epoch  6900 loss = 0.0205161
# epoch  7000 loss = 0.0204886
# epoch  7100 loss = 0.02046
# epoch  7200 loss = 0.0204264
# epoch  7300 loss = 0.0204133
# epoch  7400 loss = 0.0204027
# epoch  7500 loss = 0.0204019
# epoch  7600 loss = 0.0203798
# epoch  7700 loss = 0.0203634
# epoch  7800 loss = 0.0203417
# epoch  7900 loss = 0.0202984
# epoch  8000 loss = 0.0202981
# epoch  8100 loss = 0.0202909
# epoch  8200 loss = 0.0202753
# epoch  8300 loss = 0.0202637
# epoch  8400 loss = 0.0202411
# epoch  8500 loss = 0.0202244
# epoch  8600 loss = 0.0202177
# epoch  8700 loss = 0.0201981
# epoch  8800 loss = 0.0201813
# epoch  8900 loss = 0.0201834
# loss is nan, reverting to mdl.sav.8900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9000 loss = 0.0201677
# epoch  9100 loss = 0.0201478
# epoch  9200 loss = 0.0201354
# loss is nan, reverting to mdl.sav.9200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9300 loss = 0.0201217
# loss is nan, reverting to mdl.sav.9300
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9400 loss = 0.0201267
# loss is nan, reverting to mdl.sav.9400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9500 loss = 0.0201142
# epoch  9600 loss = 0.020107
# epoch  9700 loss = 0.0200945
# loss is nan, reverting to mdl.sav.9700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9800 loss = 0.0200811
# loss is nan, reverting to mdl.sav.9800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9900 loss = 0.0200906
# loss is nan, reverting to mdl.sav.9900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# batch_size 2048 width  256 layers 3 loss 0.0200807
# training network for 10000 epochs
# epoch     0 loss = 0.0313001
# epoch   100 loss = 0.0242164
# epoch   200 loss = 0.0234638
# epoch   300 loss = 0.0231413
# epoch   400 loss = 0.022919
# epoch   500 loss = 0.0228248
# epoch   600 loss = 0.0227545
# epoch   700 loss = 0.0226799
# epoch   800 loss = 0.0226005
# epoch   900 loss = 0.0225717
# epoch  1000 loss = 0.0225296
# epoch  1100 loss = 0.0223064
# epoch  1200 loss = 0.0222546
# epoch  1300 loss = 0.0222076
# epoch  1400 loss = 0.0221861
# epoch  1500 loss = 0.0221448
# epoch  1600 loss = 0.0221031
# epoch  1700 loss = 0.0220776
# epoch  1800 loss = 0.0220463
# epoch  1900 loss = 0.0219995
# epoch  2000 loss = 0.0219691
# epoch  2100 loss = 0.021968
# epoch  2200 loss = 0.021919
# epoch  2300 loss = 0.0218831
# epoch  2400 loss = 0.0218484
# epoch  2500 loss = 0.0217978
# epoch  2600 loss = 0.0217515
# epoch  2700 loss = 0.0217093
# epoch  2800 loss = 0.0216871
# epoch  2900 loss = 0.0216381
# epoch  3000 loss = 0.0215813
# epoch  3100 loss = 0.0215374
# epoch  3200 loss = 0.0215016
# epoch  3300 loss = 0.0214669
# epoch  3400 loss = 0.0214216
# epoch  3500 loss = 0.0213721
# epoch  3600 loss = 0.0213025
# epoch  3700 loss = 0.0212551
# epoch  3800 loss = 0.0211886
# epoch  3900 loss = 0.021141
# epoch  4000 loss = 0.0211157
# epoch  4100 loss = 0.0210556
# epoch  4200 loss = 0.0210185
# epoch  4300 loss = 0.0209561
# epoch  4400 loss = 0.0209046
# epoch  4500 loss = 0.0208769
# epoch  4600 loss = 0.0208572
# epoch  4700 loss = 0.0208021
# epoch  4800 loss = 0.0207796
# epoch  4900 loss = 0.0207506
# epoch  5000 loss = 0.020688
# epoch  5100 loss = 0.0206534
# epoch  5200 loss = 0.0206296
# epoch  5300 loss = 0.0205993
# epoch  5400 loss = 0.0205792
# epoch  5500 loss = 0.0205438
# epoch  5600 loss = 0.0205168
# epoch  5700 loss = 0.0205081
# epoch  5800 loss = 0.0204864
# epoch  5900 loss = 0.0204457
# epoch  6000 loss = 0.0204434
# epoch  6100 loss = 0.0204258
# loss is nan, reverting to mdl.sav.6100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  6200 loss = 0.0203808
# loss is nan, reverting to mdl.sav.6200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  6300 loss = 0.0203687
# epoch  6400 loss = 0.0203239
# loss is nan, reverting to mdl.sav.6400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  6500 loss = 0.0202867
# loss is nan, reverting to mdl.sav.6500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.6500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  6600 loss = 0.0202803
# loss is nan, reverting to mdl.sav.6600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  6700 loss = 0.0202671
# loss is nan, reverting to mdl.sav.6700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  6800 loss = 0.0202319
# epoch  6900 loss = 0.0202253
# epoch  7000 loss = 0.0201996
# loss is nan, reverting to mdl.sav.7000
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7100 loss = 0.0201783
# loss is nan, reverting to mdl.sav.7100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7200 loss = 0.0201649
# loss is nan, reverting to mdl.sav.7200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7300 loss = 0.0201698
# epoch  7400 loss = 0.0201659
# loss is nan, reverting to mdl.sav.7400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7500 loss = 0.0201822
# loss is nan, reverting to mdl.sav.7500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7600 loss = 0.0201768
# loss is nan, reverting to mdl.sav.7600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7700 loss = 0.020155
# loss is nan, reverting to mdl.sav.7700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7800 loss = 0.0201551
# loss is nan, reverting to mdl.sav.7800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7900 loss = 0.0201528
# loss is nan, reverting to mdl.sav.7900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8000 loss = 0.0201461
# loss is nan, reverting to mdl.sav.8000
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8100 loss = 0.0201557
# epoch  8200 loss = 0.0201452
# loss is nan, reverting to mdl.sav.8200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8300 loss = 0.0201357
# loss is nan, reverting to mdl.sav.8300
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8300
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8300
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8300
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8300
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8400 loss = 0.0201421
# loss is nan, reverting to mdl.sav.8400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8500 loss = 0.0201295
# loss is nan, reverting to mdl.sav.8500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8600 loss = 0.0201063
# loss is nan, reverting to mdl.sav.8600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8700 loss = 0.0201031
# loss is nan, reverting to mdl.sav.8700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8800 loss = 0.020102
# loss is nan, reverting to mdl.sav.8800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8900 loss = 0.0201078
# loss is nan, reverting to mdl.sav.8900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9000 loss = 0.0201165
# loss is nan, reverting to mdl.sav.9000
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9100 loss = 0.0201119
# loss is nan, reverting to mdl.sav.9100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9200 loss = 0.0201125
# epoch  9300 loss = 0.020097
# loss is nan, reverting to mdl.sav.9300
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9300
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9300
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9300
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9500 loss = 0.0200979
# loss is nan, reverting to mdl.sav.9500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9600 loss = 0.0201258
# loss is nan, reverting to mdl.sav.9600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9700 loss = 0.0201323
# loss is nan, reverting to mdl.sav.9700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9800 loss = 0.0201398
# loss is nan, reverting to mdl.sav.9800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9900 loss = 0.0201268
# loss is nan, reverting to mdl.sav.9900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# batch_size 2048 width  256 layers 4 loss 0.0201148
# training network for 10000 epochs
# epoch     0 loss = 0.0318738
# epoch   100 loss = 0.0241752
# epoch   200 loss = 0.023359
# epoch   300 loss = 0.0230547
# epoch   400 loss = 0.0228833
# epoch   500 loss = 0.0227624
# epoch   600 loss = 0.0226615
# epoch   700 loss = 0.0225708
# epoch   800 loss = 0.0225423
# epoch   900 loss = 0.0225067
# epoch  1000 loss = 0.0224647
# epoch  1100 loss = 0.0222682
# epoch  1200 loss = 0.0222299
# epoch  1300 loss = 0.0221901
# epoch  1400 loss = 0.022143
# epoch  1500 loss = 0.0221178
# epoch  1600 loss = 0.0220899
# epoch  1700 loss = 0.0220734
# epoch  1800 loss = 0.0220262
# epoch  1900 loss = 0.0219733
# epoch  2000 loss = 0.0219481
# epoch  2100 loss = 0.0219089
# epoch  2200 loss = 0.02187
# epoch  2300 loss = 0.0218422
# epoch  2400 loss = 0.0217981
# epoch  2500 loss = 0.0217426
# epoch  2600 loss = 0.0216993
# epoch  2700 loss = 0.0216292
# epoch  2800 loss = 0.0215847
# epoch  2900 loss = 0.0215478
# epoch  3000 loss = 0.02148
# epoch  3100 loss = 0.0214249
# epoch  3200 loss = 0.0213481
# epoch  3300 loss = 0.0212814
# epoch  3400 loss = 0.0212527
# epoch  3500 loss = 0.0212158
# epoch  3600 loss = 0.0211717
# epoch  3700 loss = 0.0211438
# epoch  3800 loss = 0.0210924
# epoch  3900 loss = 0.0210392
# epoch  4000 loss = 0.0209908
# epoch  4100 loss = 0.0209454
# epoch  4200 loss = 0.020905
# epoch  4300 loss = 0.0208467
# loss is nan, reverting to mdl.sav.4300
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  4400 loss = 0.0207908
# loss is nan, reverting to mdl.sav.4400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.4400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.4400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.4400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  4500 loss = 0.0207283
# epoch  4600 loss = 0.0206623
# loss is nan, reverting to mdl.sav.4600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  4700 loss = 0.020627
# epoch  4800 loss = 0.0205779
# loss is nan, reverting to mdl.sav.4800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  4900 loss = 0.0205577
# loss is nan, reverting to mdl.sav.4900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  5000 loss = 0.0205148
# loss is nan, reverting to mdl.sav.5000
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.5000
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.5000
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.5000
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  5100 loss = 0.0204902
# epoch  5200 loss = 0.02046
# loss is nan, reverting to mdl.sav.5200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  5300 loss = 0.0204513
# epoch  5400 loss = 0.0204229
# loss is nan, reverting to mdl.sav.5400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.5400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.5400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  5500 loss = 0.0204179
# loss is nan, reverting to mdl.sav.5500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  5600 loss = 0.0204262
# loss is nan, reverting to mdl.sav.5600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.5600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.5600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  5700 loss = 0.0204302
# loss is nan, reverting to mdl.sav.5700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.5700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.5700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.5700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  5800 loss = 0.0204194
# loss is nan, reverting to mdl.sav.5800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  5900 loss = 0.0204198
# loss is nan, reverting to mdl.sav.5900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  6000 loss = 0.020429
# loss is nan, reverting to mdl.sav.6000
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.6000
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  6100 loss = 0.0204059
# loss is nan, reverting to mdl.sav.6100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.6100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.6100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.6100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.6100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.6100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.6100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  6200 loss = 0.0204205
# loss is nan, reverting to mdl.sav.6200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  6300 loss = 0.020406
# epoch  6400 loss = 0.0204032
# loss is nan, reverting to mdl.sav.6400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  6500 loss = 0.0203993
# loss is nan, reverting to mdl.sav.6500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  6600 loss = 0.0203906
# loss is nan, reverting to mdl.sav.6600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.6600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  6700 loss = 0.0203742
# loss is nan, reverting to mdl.sav.6700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.6700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.6700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  6800 loss = 0.0203513
# loss is nan, reverting to mdl.sav.6800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  6900 loss = 0.0203617
# loss is nan, reverting to mdl.sav.6900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.6900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.6900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7000 loss = 0.020358
# loss is nan, reverting to mdl.sav.7000
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7100 loss = 0.0203428
# loss is nan, reverting to mdl.sav.7100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7200 loss = 0.0203221
# loss is nan, reverting to mdl.sav.7200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7300 loss = 0.0202978
# loss is nan, reverting to mdl.sav.7300
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7400 loss = 0.0202945
# epoch  7500 loss = 0.020275
# loss is nan, reverting to mdl.sav.7500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7600 loss = 0.0202764
# epoch  7700 loss = 0.0202578
# loss is nan, reverting to mdl.sav.7700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7800 loss = 0.0202609
# loss is nan, reverting to mdl.sav.7800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7900 loss = 0.0202463
# loss is nan, reverting to mdl.sav.7900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8000 loss = 0.0202259
# loss is nan, reverting to mdl.sav.8000
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8100 loss = 0.0202334
# loss is nan, reverting to mdl.sav.8100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8200 loss = 0.0202559
# loss is nan, reverting to mdl.sav.8200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8300 loss = 0.0202507
# loss is nan, reverting to mdl.sav.8300
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8300
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8400 loss = 0.0202364
# loss is nan, reverting to mdl.sav.8400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8500 loss = 0.0202501
# epoch  8600 loss = 0.020249
# loss is nan, reverting to mdl.sav.8600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8700 loss = 0.0202478
# loss is nan, reverting to mdl.sav.8700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8800 loss = 0.0202491
# loss is nan, reverting to mdl.sav.8800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8900 loss = 0.0202583
# loss is nan, reverting to mdl.sav.8900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9000 loss = 0.0202638
# loss is nan, reverting to mdl.sav.9000
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9000
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9000
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9000
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9000
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9100 loss = 0.0202468
# loss is nan, reverting to mdl.sav.9100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9100
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9200 loss = 0.0202233
# loss is nan, reverting to mdl.sav.9200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9300 loss = 0.0201976
# loss is nan, reverting to mdl.sav.9300
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9400 loss = 0.0201961
# loss is nan, reverting to mdl.sav.9400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9500 loss = 0.0201928
# loss is nan, reverting to mdl.sav.9500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9600 loss = 0.020188
# loss is nan, reverting to mdl.sav.9600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9700 loss = 0.0201941
# loss is nan, reverting to mdl.sav.9700
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9800 loss = 0.0201751
# loss is nan, reverting to mdl.sav.9800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  9900 loss = 0.0201797
# loss is nan, reverting to mdl.sav.9900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.9900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# batch_size 2048 width  256 layers 5 loss 0.0201617
# training network for 10000 epochs
# epoch     0 loss = 0.0317499
# epoch   100 loss = 0.023828
# epoch   200 loss = 0.0231727
# epoch   300 loss = 0.0229147
# epoch   400 loss = 0.0227434
# epoch   500 loss = 0.022649
# epoch   600 loss = 0.0225704
# epoch   700 loss = 0.0225239
# epoch   800 loss = 0.0224594
# epoch   900 loss = 0.0224098
# epoch  1000 loss = 0.0223795
# epoch  1100 loss = 0.0221987
# epoch  1200 loss = 0.0221707
# epoch  1300 loss = 0.0221501
# epoch  1400 loss = 0.0221144
# epoch  1500 loss = 0.0220775
# epoch  1600 loss = 0.0220353
# epoch  1700 loss = 0.0219894
# epoch  1800 loss = 0.0219443
# epoch  1900 loss = 0.0218954
# epoch  2000 loss = 0.0218216
# epoch  2100 loss = 0.0217737
# epoch  2200 loss = 0.0216998
# epoch  2300 loss = 0.0216148
# epoch  2400 loss = 0.0215695
# epoch  2500 loss = 0.0215079
# epoch  2600 loss = 0.0214598
# epoch  2700 loss = 0.0214033
# epoch  2800 loss = 0.0213628
# epoch  2900 loss = 0.0213099
# epoch  3000 loss = 0.0212586
# epoch  3100 loss = 0.0211906
# epoch  3200 loss = 0.0211088
# epoch  3300 loss = 0.0210564
# epoch  3400 loss = 0.0209874
# epoch  3500 loss = 0.0209228
# epoch  3600 loss = 0.0208576
# epoch  3700 loss = 0.0207992
# epoch  3800 loss = 0.0207367
# epoch  3900 loss = 0.0206942
# epoch  4000 loss = 0.0206346
# epoch  4100 loss = 0.0205978
# epoch  4200 loss = 0.0205667
# epoch  4300 loss = 0.0205229
# epoch  4400 loss = 0.0204968
# epoch  4500 loss = 0.020455
# epoch  4600 loss = 0.0204088
# epoch  4700 loss = 0.0203669
# epoch  4800 loss = 0.0203351
# epoch  4900 loss = 0.0202995
# epoch  5000 loss = 0.020282
# epoch  5100 loss = 0.0202389
# epoch  5200 loss = 0.0202247
# epoch  5300 loss = 0.0201944
# epoch  5400 loss = 0.0201716
# epoch  5500 loss = 0.0201592
# epoch  5600 loss = 0.0201426
# epoch  5700 loss = 0.0201162
# epoch  5800 loss = 0.0200927
# epoch  5900 loss = 0.0200788
# epoch  6000 loss = 0.0200732
# epoch  6100 loss = 0.0200667
# epoch  6200 loss = 0.0200513
# epoch  6300 loss = 0.0200311
# epoch  6400 loss = 0.0200026
# epoch  6500 loss = 0.0199895
# epoch  6600 loss = 0.0199907
# loss is nan, reverting to mdl.sav.6600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  6700 loss = 0.019986
# epoch  6800 loss = 0.0199651
# loss is nan, reverting to mdl.sav.6800
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  6900 loss = 0.0199457
# epoch  7000 loss = 0.0199103
# loss is nan, reverting to mdl.sav.7000
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7100 loss = 0.0198953
# epoch  7200 loss = 0.0198774
# epoch  7300 loss = 0.0198692
# loss is nan, reverting to mdl.sav.7300
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.7300
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7400 loss = 0.01986
# loss is nan, reverting to mdl.sav.7400
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7500 loss = 0.019835
# loss is nan, reverting to mdl.sav.7500
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7600 loss = 0.0198169
# loss is nan, reverting to mdl.sav.7600
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  7700 loss = 0.0198055
# epoch  7800 loss = 0.019804
# epoch  7900 loss = 0.0198162
# loss is nan, reverting to mdl.sav.7900
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8000 loss = 0.0198184
# epoch  8100 loss = 0.0198195
# epoch  8200 loss = 0.0198076
# loss is nan, reverting to mdl.sav.8200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# loss is nan, reverting to mdl.sav.8200
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# epoch  8300 loss = 0.0198134
# loss is nan, reverting to mdl.sav.8300
# ...
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_5_layer_call_fn, dropout_5_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_5_layer_call_fn while saving (showing 5 of 40). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_5_layer_call_fn, dropout_5_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_5_layer_call_fn while saving (showing 5 of 40). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_5_layer_call_fn, dropout_5_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_5_layer_call_fn while saving (showing 5 of 40). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_5_layer_call_fn, dropout_5_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_5_layer_call_fn while saving (showing 5 of 40). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_5_layer_call_fn, dropout_5_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_5_layer_call_fn while saving (showing 5 of 40). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_5_layer_call_fn, dropout_5_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_5_layer_call_fn while saving (showing 5 of 40). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_5_layer_call_fn, dropout_5_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_5_layer_call_fn while saving (showing 5 of 40). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_5_layer_call_fn, dropout_5_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_5_layer_call_fn while saving (showing 5 of 40). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_5_layer_call_fn, dropout_5_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_5_layer_call_fn while saving (showing 5 of 40). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_5_layer_call_fn, dropout_5_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_5_layer_call_fn while saving (showing 5 of 40). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_5_layer_call_fn, dropout_5_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_5_layer_call_fn while saving (showing 5 of 40). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_5_layer_call_fn, dropout_5_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_5_layer_call_fn while saving (showing 5 of 40). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_5_layer_call_fn, dropout_5_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_5_layer_call_fn while saving (showing 5 of 40). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_5_layer_call_fn, dropout_5_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_5_layer_call_fn while saving (showing 5 of 40). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_5_layer_call_fn, dropout_5_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_5_layer_call_fn while saving (showing 5 of 40). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_5_layer_call_fn, dropout_5_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_5_layer_call_fn while saving (showing 5 of 40). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_5_layer_call_fn, dropout_5_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_5_layer_call_fn while saving (showing 5 of 40). These functions will not be directly callable after loading.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:Found untraced functions such as dropout_5_layer_call_fn, dropout_5_layer_call_and_return_conditional_losses, action_logits_layer_call_fn, action_logits_layer_call_and_return_conditional_losses, softmax_5_layer_call_fn while saving (showing 5 of 40). These functions will not be directly callable after loading.

# %%
def foo():
    pass
    # x, mask, y = election_memory.get_batch(1)
    # o = network(x)
    # print(x)
    #
    # xx = np.arange(0, n_bins)
    # plt.plot(o.numpy()[0])
    #
    # plt.scatter(xx, x.numpy()[0])
